# %% [markdown]
# ## Practicing Functions in Python

# %% [markdown]
# ### Problem Description:
# You are given a temperature in Celsius. Your task is to convert it to Fahrenheit and return the result.
#
# Formula:
#
# To calculate the area of a rectangle:
#
# F = (9/5 * C) + 32

# %%
def celsius_to_fahrenheit(C):
    """
    Function to convert temperature from Celsius to Fahrenheit.
    
    Parameters:
    C (float): The temperature in Celsius.
    
    Returns:
    float: The temperature in Fahrenheit.
    """
    F = (9/5 * C) + 32
    return F

temp = float(input("Enter the temperature in Celsius: "))
print(f"The temperature in Fahrenheit is {celsius_to_fahrenheit(temp)}")
# Out:
# The temperature in Fahrenheit is 32.0

# %% [markdown]
# ### Problem Description:
# You are given the length and breadth of a rectangle. Your task is to compute and return the area of the rectangle.
#
# Formula:
#
# To calculate the area of a rectangle:
#
# Area=length×breadth

# %%
def area_of_rectangle(l, b):
    """
    Function to calculate the area of a rectangle.
    
    Parameters:
    l (float): The length of the rectangle.
    b (float): The breadth of the rectangle.
    
    Returns:
    float: The area of the rectangle.
    """
    area = l*b
    return area

length = float(input("Enter the length of the rectangle: "))
breadth = float(input("Enter the breadth of the rectangle: "))
print(f"The area of rectangle with length {length}cm and breadth {breadth}cm is {area_of_rectangle(length, breadth)}")
# Out:
# The area of rectangle with length 20.0cm and breadth 30.0cm is 600.0

# %% [markdown]
# ### Problem Description:
#
# You are given the speed of a vehicle and the time it has traveled. Your task is to compute and return the distance traveled by the vehicle.
#
# Formula:
#
# To calculate the distance traveled by a vehicle:
#
# Distance=Speed×Time

# %%
def calculate_distance(s, t):
    """
    Function to calculate the distance traveled by a vehicle.
    
    Parameters:
    s (float): The speed of the vehicle.
    t (float): The time the vehicle has traveled.
    
    Returns:
    float: The distance traveled by the vehicle.
    """
    distance = s*t
    return distance

speed = float(input("Enter the speed of the vehichle: "))
time = float(input("Enter the time travelled by the vehicle: "))
print(f"The distance covered by the vehicle is {calculate_distance(speed, time)}")
# Out:
# The distance covered by the vehicle is 120.0

# %% [markdown]
# ### Problem Description:
#
# You are given n, the total number of people, and capacity, the maximum number of people the lift can carry at a time. All people want to go from the ground floor to the top floor. Your task is to calculate the number of rounds the lift has to make to transport all the people to the top floor.

# %%
import math
def calculate_lift_rounds(n, capacity):
    """
    Function to calculate the number of rounds the lift needs to cover.
    
    Parameters:
    n (int): Total number of people.
    capacity (int): Maximum number of people the lift can carry in one round.
    
    Returns:
    int: The number of rounds required to transport all people to the top floor.
    """
    if n == capacity:
        trips = 1
    else:
        trips = math.ceil(n / capacity)
    return trips

n = int(input("Enter the total number of people: "))
capacity = int(input("Enter the capacity of the lift: "))
print(f"The lift takes {calculate_lift_rounds(n, capacity)} rounds to transport {n} people.")
# Out:
# The lift takes 2 rounds to transport 20 people.

# %% [markdown]
# ### Problem Description:
#
# You are given the slope m and the y-intercept b of a line, along with a value x. Your task is to calculate and return the value of y using the equation of a line in slope-intercept form:
#
# y=mx+b

# %%
def calculate_y(m, b, x):
    """
    Function to calculate the value of y using the slope-intercept form of a line.
    
    Parameters:
    slope (float): The slope of the line.
    intercept (float): The y-intercept of the line.
    x (float): The value of x for which y needs to be calculated.
    
    Returns:
    float: The calculated value of y.
    """

    y = (m*x) + b
    return y

slope = float(input("Enter the slope value of the line: "))
intercept = float(input("Enter the value of intercept of the line: "))
x = float(input("Enter the value of x: "))
y = calculate_y(slope, intercept, x)
print(f"Y along X-axis : {y}")
# Out:
# Y along X-axis : 1.0

# %%
print(celsius_to_fahrenheit(25))
print(area_of_rectangle(5, 10))
print(calculate_distance(60, 2))
print(calculate_lift_rounds(17, 5))
print(calculate_y(2, 3, 4))
# Out:
# 77.0
# 50
# 120
# 4
# 11
