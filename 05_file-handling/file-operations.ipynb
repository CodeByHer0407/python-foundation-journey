# %% [markdown]
# ## File Operation - Read And Write Files

# %% [markdown]
# File handling is a crucial part of any programming language. Python provides built-in functions and methods to read from and write to files, both text and binary.

# %%
import os

# %% [markdown]
# ### ===== READ FILE =====

# %%
## Read a whole file

with open('example.txt', "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, how are you?
# I am good!
# Welcome to my repo!

# %%
## Read a file line by line

with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, how are you?
# I am good!
# My name is Saloni.
# Welcome to my repo!

# %%
# Show the current working directory of your notebook
print(os.getcwd())

# Show the absolute path of the file you just wrote
print(os.path.abspath("example.txt"))
# Out:
# c:\Users\Shizi\OneDrive\Desktop\LEARNINGS\python-foundation-journey\05_file-handling
# c:\Users\Shizi\OneDrive\Desktop\LEARNINGS\python-foundation-journey\05_file-handling\example.txt

# %% [markdown]
# ### ===== WRITE FILE =====

# %%
## Writing a file (Overwriting)

with open('example.txt', "w") as file:
    file.write("Hey, I am Saloni.\n")
    file.write("Welcome to my World!!\n")

# %%
## Writing a file (without overwriting)

with open('example.txt', "a") as file:
    file.write("Append operation taking place now...")

# %%
## Writing a list of lines to a file

lines = ['First line \n', 'Second line \n', 'Third line\n']
with open('example.txt', "a") as file:
    file.writelines(lines)

# %%
## Binary Files

# Writing to a binary file

data = b'\x00\x01\x02\x03\x04'
with open('examples.bin', "wb") as file:
    file.write(data)

# %%
## Reading a binary file

with open("examples.bin", "rb") as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
### Read the content from a source text file and write it to a destination text file

with open('source.txt', "r") as source_file:
    content = source_file.read()

with open('destination.txt', "w") as destination_file:
    destination_file.write(content)

# %%
## Read a text file and count the number of lines, words, and characters.

with open('example.txt', "r") as file:
    content = file.read()
    lines = len(content.splitlines())
    words = len(content.split())
    characters = len(content)

    print(f"Number of lines: {lines}")
    print(f"Number of words: {words}")
    print(f"Number of characters: {characters}")
# Out:
# Number of lines: 3
# Number of words: 7
# Number of characters: 35

# %% [markdown]
# The w+ mode in Python is used to open a file for both reading and writing. If the files does not exist, it will be created, its content is truncated(i.e., the file is overwritten).

# %%
## Writing and then reading a file

with open('example.txt', "w+") as file:
    file.write("Hey, hello world!\n")
    file.write("Adding a new line here \n")

    ## Move the file cursor to the beginning

    file.seek(0)

    ## Read the content of the file
    content = file.read()
    print(content)
# Out:
# Hey, hello world!
# Adding a new line here
