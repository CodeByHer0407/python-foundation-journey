# %% [markdown]
# ## Standard Library Overview

# %% [markdown]
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box.

# %%
import array

arr = array.array('i', [10, 20, 30, 40])
print(arr)

# %%
import math

math.sqrt(100)
# Out:
# 10.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
## random

import random

print(random.randint(1, 100))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 100
# cherry

# %%
### File and Directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\Shizi\OneDrive\Desktop\LEARNINGS\python-foundation-journey\09_modules

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files

import shutil

shutil.copy('source.txt', 'destionation.txt')
# Out:
# 'destionation.txt'

# %%
## Data Serialization

import json

data = {'name': 'Saloni', 'age': 27}

print(type(data))

json_str = json.dumps(data)
print(json_str)
print(type(json_str))


parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# <class 'dict'>
# {"name": "Saloni", "age": 27}
# <class 'str'>
# {'name': 'Saloni', 'age': 27}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv', mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Saloni', 26])

with open('example.csv', "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Saloni', '26']

# %%
## datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days = 1)
print(yesterday)
# Out:
# 2026-03-23 13:51:10.626491
# 2026-03-22 13:51:10.626491

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1774254134.2237632
# 1774254136.2337587

# %%
## Regular Expression

import re

pattern = r'\d+'
text = 'There are 123 apples 456'

match = re.search(pattern, text)
print(match.group())
# Out:
# 123
